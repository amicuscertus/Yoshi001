# %% [markdown]
# <a href="https://colab.research.google.com/github/amicuscertus/Yoshi001/blob/master/Yoshi001.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('http://academia.rdy.jp/bioinf/wp-content/uploads/2019/05/Subjectdata.csv')
df.describe()
# Out:
#        Project Site       Height  ...  Unnamed: 71  Unnamed: 72
# count   5700.000000  4554.000000  ...          0.0          0.0
# mean       9.555965   168.047811  ...          NaN          NaN
# std        6.340864    10.846051  ...          NaN          NaN
# min        1.000000   124.970000  ...          NaN          NaN
# 25%        4.000000   160.020000  ...          NaN          NaN
# 50%        8.000000   167.890000  ...          NaN          NaN
# 75%       15.000000   176.020000  ...          NaN          NaN
# max       21.000000   202.000000  ...          NaN          NaN
#
# [8 rows x 34 columns]

# %%
df.isnull().sum()
# Out:
# PharmGKB Subject ID                                                        0
# PharmGKB Sample ID                                                         0
# Project Site                                                               0
# Gender                                                                     4
# Race (Reported)                                                          506
# Race (OMB)                                                                 0
# Ethnicity (Reported)                                                    1239
# Ethnicity (OMB)                                                            0
# Age                                                                       42
# Height                                                                  1146
# Weight                                                                   287
# Indication for Warfarin Treatment                                        698
# Comorbidities                                                           1955
# Diabetes                                                                2417
# Congestive Heart Failure and/or Cardiomyopathy                          1688
# Valve Replacement                                                       1742
# Medications                                                             1397
# Aspirin                                                                 1860
# Acetaminophen or Paracetamol (Tylenol)                                  3426
# Was Dose of Acetaminophen or Paracetamol (Tylenol) >1300mg/day          4541
# Simvastatin (Zocor)                                                     1839
# Atorvastatin (Lipitor)                                                  3245
# Fluvastatin (Lescol)                                                    3277
# Lovastatin (Mevacor)                                                    3269
# Pravastatin (Pravachol)                                                 3267
# Rosuvastatin (Crestor)                                                  3276
# Cerivastatin (Baycol)                                                   3564
# Amiodarone (Cordarone)                                                  1518
# Carbamazepine (Tegretol)                                                3270
# Phenytoin (Dilantin)                                                    3276
#                                                                         ...
# Genotyped QC Cyp2C9*3                                                   5222
# Combined QC CYP2C9                                                      5222
# VKORC1 genotype: -1639 G>A (3673); chr16:31015190; rs9923231; C/T       1654
# VKORC1 QC genotype: -1639 G>A (3673); chr16:31015190; rs9923231; C/T    5222
# VKORC1 genotype: 497T>G (5808); chr16:31013055; rs2884737; A/C          4101
# VKORC1 QC genotype: 497T>G (5808); chr16:31013055; rs2884737; A/C       5222
# VKORC1 genotype: 1173 C>T(6484); chr16:31012379; rs9934438; A/G         2337
# VKORC1 QC genotype: 1173 C>T(6484); chr16:31012379; rs9934438; A/G      5222
# VKORC1 genotype: 1542G>C (6853); chr16:31012010; rs8050894; C/G         2370
# VKORC1 QC genotype: 1542G>C (6853); chr16:31012010; rs8050894; C/G      5222
# VKORC1 genotype: 3730 G>A (9041); chr16:31009822; rs7294;  A/G          2576
# VKORC1 QC genotype: 3730 G>A (9041); chr16:31009822; rs7294;  A/G       5222
# VKORC1 genotype: 2255C>T (7566); chr16:31011297; rs2359612; A/G         3477
# VKORC1 QC genotype: 2255C>T (7566); chr16:31011297; rs2359612; A/G      5222
# VKORC1 genotype: -4451 C>A (861); Chr16:31018002; rs17880887; A/C       5160
# VKORC1 QC genotype: -4451 C>A (861); Chr16:31018002; rs17880887; A/C    5249
# CYP2C9 consensus                                                         144
# VKORC1 -1639 consensus                                                  1499
# VKORC1 497 consensus                                                    3817
# VKORC1 1173 consensus                                                   2109
# VKORC1 1542 consensus                                                   2179
# VKORC1 3730 consensus                                                   2356
# VKORC1 2255 consensus                                                   3164
# VKORC1 -4451 consensus                                                  4788
# Comments regarding Project Site Dataset                                 5543
# Unnamed: 68                                                             5700
# Unnamed: 69                                                             5700
# Unnamed: 70                                                             5700
# Unnamed: 71                                                             5700
# Unnamed: 72                                                             5700
# Length: 73, dtype: int64

# %%
df["Height"].plot()
df["Weight"].plot()
df["Therapeutic Dose of Warfarin"].plot()

# %%
df = df.loc[:, ["Therapeutic Dose of Warfarin", "Height", "Weight", "Gender", "Age"]]
df.describe()
# Out:
#        Therapeutic Dose of Warfarin       Height       Weight
# count                   5528.000000  4554.000000  5413.000000
# mean                      30.977873   168.047811    77.853057
# std                       16.801040    10.846051    21.860018
# min                        2.100000   124.970000    30.000000
# 25%                       19.530000   160.020000    62.000000
# 50%                       28.000000   167.890000    75.000000
# 75%                       38.500000   176.020000    90.000000
# max                      315.000000   202.000000   237.700000

# %%
df.tail(2)
# Out:
#       Therapeutic Dose of Warfarin  Height  Weight Gender      Age
# 5698                         70.00   177.8    87.3   male  60 - 69
# 5699                         24.01   190.5    79.6   male  70 - 79

# %%
df.isnull().sum()
# Out:
# Therapeutic Dose of Warfarin     172
# Height                          1146
# Weight                           287
# Gender                             4
# Age                               42
# dtype: int64

# %%
df.dropna(inplace=True)
df.isnull().sum()
# Out:
# Therapeutic Dose of Warfarin    0
# Height                          0
# Weight                          0
# Gender                          0
# Age                             0
# dtype: int64

# %%
df["Height"].plot()
df["Weight"].plot()
df["Therapeutic Dose of Warfarin"].plot()

# %%
df.tail(2)
# Out:
#       Therapeutic Dose of Warfarin  Height  Weight Gender      Age
# 5698                         70.00   177.8    87.3   male  60 - 69
# 5699                         24.01   190.5    79.6   male  70 - 79

# %%
df.describe()
# Out:
#        Therapeutic Dose of Warfarin       Height       Weight
# count                   4384.000000  4384.000000  4384.000000
# mean                      31.366248   168.131784    78.443932
# std                       17.078137    10.848873    22.119276
# min                        2.100000   124.970000    30.000000
# 25%                       20.000000   160.020000    63.000000
# 50%                       28.000000   167.890000    75.000000
# 75%                       39.970000   176.020000    90.500000
# max                      315.000000   202.000000   237.700000

# %%
df.reset_index(inplace=True)
df.tail()
# Out:
#       index  Therapeutic Dose of Warfarin  Height  Weight  Gender      Age
# 4379   5695                         52.50  185.42   113.6    male  20 - 29
# 4380   5696                         27.51  160.02    55.9  female  70 - 79
# 4381   5697                         57.47  187.96    97.7    male  60 - 69
# 4382   5698                         70.00  177.80    87.3    male  60 - 69
# 4383   5699                         24.01  190.50    79.6    male  70 - 79

# %%
df["Height"].plot()
df["Weight"].plot()
df["Therapeutic Dose of Warfarin"].plot()

# %%
sns.pairplot(df[["Height", "Weight", "Therapeutic Dose of Warfarin"]], diag_kind="kde")

# %%
sns.distplot(df["Height"])
sns.distplot(df["Weight"])
sns.distplot(df["Therapeutic Dose of Warfarin"])
